# %% [markdown]
# ## Pillow experimenting

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
im = Image.open('face_images/image_0026.jpg') #.convert("L") # converts to grayscale

# %%
print(im.format, im.size, im.mode)
# Out:
# JPEG (896, 592) RGB

# %%
scale = 0.3
thumbnail_size = (im.size[0] * scale, im.size[1] * scale)

# %%
im.thumbnail(thumbnail_size)
im
# im.save("thumbnail_img.jpg", "JPEG")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=268x177 at 0x7FA109EB1940>

# %% [markdown]
# ### Convert Image to numpy array

# %%
face_img_3D_array = np.array(im)
face_img_1D_array = np.ravel(face_img_array)

# %% [markdown]
# ### Create random image

# %%
rand_img_array = np.random.randint(0, 255, size=(150, 500, 3)).astype('uint8')

# %%
rand_im = Image.fromarray(rand_img_array)

# %%
rand_im
# Out:
# <PIL.Image.Image image mode=RGB size=500x150 at 0x7FA109E5A048>

# %%
plt.imshow(rand_img_array)
